# %% [markdown]
# **CAR DATA ANALYSIS (EDA)**
# - I am a huge fan of cars,I contains features of the car such as Engine Fuel Type, Engine HP, Transmission Type, highway MPG, city MPG and many more.
# **QUESTIONS **
# -Remove the duplicate rows that can display repeatedly?
# -Count the total number of car manufactured in different companys?
# -find the correlation between two variables?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/content/data.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df=pd.read_csv('/content/data.csv')
df.tail(10)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11904      BMW      Z8  2002     premium unleaded (required)      394.0
# 11905      BMW      Z8  2003     premium unleaded (required)      394.0
# 11906    Acura     ZDX  2011     premium unleaded (required)      300.0
# 11907    Acura     ZDX  2011     premium unleaded (required)      300.0
# 11908    Acura     ZDX  2011     premium unleaded (required)      300.0
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11904               8.0            MANUAL   rear wheel drive              2.0
# ...

# %%
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df = df.drop(['Year', 'Popularity', 'MSRP', 'Number of Doors', 'Vehicle Size'], axis=1)
df
# Out:
#           Make       Model                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M     premium unleaded (required)      335.0
# 1          BMW    1 Series     premium unleaded (required)      300.0
# 2          BMW    1 Series     premium unleaded (required)      300.0
# 3          BMW    1 Series     premium unleaded (required)      230.0
# 4          BMW    1 Series     premium unleaded (required)      230.0
# ...        ...         ...                             ...        ...
# 11909    Acura         ZDX     premium unleaded (required)      300.0
# 11910    Acura         ZDX     premium unleaded (required)      300.0
# 11911    Acura         ZDX     premium unleaded (required)      300.0
# 11912    Acura         ZDX  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  \
# 0                   6.0            MANUAL   rear wheel drive
# ...

# %%
df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
df.tail(5)
# Out:
#           Make   Model                Engine Fuel Type     HP  Cylinders  \
# 11909    Acura     ZDX     premium unleaded (required)  300.0        6.0
# 11910    Acura     ZDX     premium unleaded (required)  300.0        6.0
# 11911    Acura     ZDX     premium unleaded (required)  300.0        6.0
# 11912    Acura     ZDX  premium unleaded (recommended)  300.0        6.0
# 11913  Lincoln  Zephyr                regular unleaded  221.0        6.0
#
#       Transmission         Drive Mode             Market Category  \
# 11909    AUTOMATIC    all wheel drive  Crossover,Hatchback,Luxury
# 11910    AUTOMATIC    all wheel drive  Crossover,Hatchback,Luxury
# 11911    AUTOMATIC    all wheel drive  Crossover,Hatchback,Luxury
# 11912    AUTOMATIC    all wheel drive  Crossover,Hatchback,Luxury
# 11913    AUTOMATIC  front wheel drive                      Luxury
#
#        Vehicle Style  MPG-H  MPG-C
# 11909  4dr Hatchback     23     16
# 11910  4dr Hatchback     23     16
# ...

# %%
df.shape
# Out:
# (11914, 11)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (7486, 11)

# %%
df.count()
# Out:
# Make                11914
# Model               11914
# Engine Fuel Type    11911
# HP                  11845
# Cylinders           11884
# Transmission        11914
# Drive Mode          11914
# Market Category      8172
# Vehicle Style       11914
# MPG-H               11914
# MPG-C               11914
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(15)
# Out:
#     Make       Model             Engine Fuel Type     HP  Cylinders  \
# 0    BMW  1 Series M  premium unleaded (required)  335.0        6.0
# 1    BMW    1 Series  premium unleaded (required)  300.0        6.0
# 2    BMW    1 Series  premium unleaded (required)  300.0        6.0
# 3    BMW    1 Series  premium unleaded (required)  230.0        6.0
# 4    BMW    1 Series  premium unleaded (required)  230.0        6.0
# 6    BMW    1 Series  premium unleaded (required)  300.0        6.0
# 9    BMW    1 Series  premium unleaded (required)  230.0        6.0
# 11   BMW    1 Series  premium unleaded (required)  230.0        6.0
# 13   BMW    1 Series  premium unleaded (required)  230.0        6.0
# 15   BMW    1 Series  premium unleaded (required)  320.0        6.0
# 16   BMW    1 Series  premium unleaded (required)  320.0        6.0
# 17  Audi         100             regular unleaded  172.0        6.0
# 19  Audi         100             regular unleaded  172.0        6.0
# ...

# %%
df.count()
# Out:
# Make                4428
# Model               4428
# Engine Fuel Type    4427
# HP                  4395
# Cylinders           4419
# Transmission        4428
# Drive Mode          4428
# Market Category     3094
# Vehicle Style       4428
# MPG-H               4428
# MPG-C               4428
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Make                   0
# Model                  0
# Engine Fuel Type       1
# HP                    33
# Cylinders              9
# Transmission           0
# Drive Mode             0
# Market Category     1334
# Vehicle Style          0
# MPG-H                  0
# MPG-C                  0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Make                3057
# Model               3057
# Engine Fuel Type    3057
# HP                  3057
# Cylinders           3057
# Transmission        3057
# Drive Mode          3057
# Market Category     3057
# Vehicle Style       3057
# MPG-H               3057
# MPG-C               3057
# dtype: int64

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# Make                0
# Model               0
# Engine Fuel Type    0
# HP                  0
# Cylinders           0
# Transmission        0
# Drive Mode          0
# Market Category     0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# dtype: int64

# %%
sns.boxplot(x=df['HP'])
# Out:
# <Axes: xlabel='HP'>

# %%
sns.boxplot(x=df['MPG-H'])
# Out:
# <Axes: xlabel='MPG-H'>

# %%
sns.boxplot(x=df['Cylinders'])
# Out:
# <Axes: xlabel='Cylinders'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# HP           137.0
# Cylinders      4.0
# MPG-H          7.0
# MPG-C          6.0
# dtype: float64
# <ipython-input-30-d7397e803310>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# <ipython-input-30-d7397e803310>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make');

# %%
sns.displot(df['Vehicle Style'])

# %%
sns.displot(df['Make'])

# %%
sns.pairplot(df)
df.head(15)
# Out:
#     Make       Model             Engine Fuel Type     HP  Cylinders  \
# 0    BMW  1 Series M  premium unleaded (required)  335.0        6.0
# 1    BMW    1 Series  premium unleaded (required)  300.0        6.0
# 2    BMW    1 Series  premium unleaded (required)  300.0        6.0
# 3    BMW    1 Series  premium unleaded (required)  230.0        6.0
# 4    BMW    1 Series  premium unleaded (required)  230.0        6.0
# 6    BMW    1 Series  premium unleaded (required)  300.0        6.0
# 9    BMW    1 Series  premium unleaded (required)  230.0        6.0
# 11   BMW    1 Series  premium unleaded (required)  230.0        6.0
# 13   BMW    1 Series  premium unleaded (required)  230.0        6.0
# 15   BMW    1 Series  premium unleaded (required)  320.0        6.0
# 16   BMW    1 Series  premium unleaded (required)  320.0        6.0
# 17  Audi         100             regular unleaded  172.0        6.0
# 19  Audi         100             regular unleaded  172.0        6.0
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-37-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['MPG-H'], df['HP'])
ax.set_xlabel('MPG-H')
ax.set_ylabel('HP')
plt.show()

# %%
df.corr()
# Out:
# <ipython-input-43-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  HP  Cylinders     MPG-H     MPG-C
# HP         1.000000   0.811068 -0.388927 -0.507904
# Cylinders  0.811068   1.000000 -0.510829 -0.627689
# MPG-H     -0.388927  -0.510829  1.000000  0.693244
# MPG-C     -0.507904  -0.627689  0.693244  1.000000
